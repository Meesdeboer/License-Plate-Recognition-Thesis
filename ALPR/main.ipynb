# %%
from ALPR import alpr
from match_license_plate import match_license_plate_to_database
from PIL import Image
# Out:
# 2024-06-02 14:48:40.690202: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-02 14:48:40.690289: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-02 14:48:40.690334: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
IMAGE_PATH = "../../test_images/AEB/not_detected/not9+IMG_2199.MOV.jpg"
img = Image.open(IMAGE_PATH)
img.resize((300, 300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
try:
    result = alpr(IMAGE_PATH)
    print("Predicted license plate:",result)
    match, count = match_license_plate_to_database(result, "lp_database.txt")
    print("Matched license plate:",match)
    print("Number of matches:",count)
except:
    print("No license plates found in the image.")
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/ALPR/../../test_images/AEB/not_detected/not9+IMG_2199.MOV.jpg: 384x640 (no detections), 441.8ms
# Speed: 4.3ms preprocess, 441.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# No license plates found in the image.
