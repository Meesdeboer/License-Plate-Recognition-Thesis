# %%
import ALPR
from ALPR import alpr
# Out:
# 2024-05-06 14:55:38.631594: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 14:55:38.631638: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 14:55:38.631659: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
IMAGE_PATH = "../test_notebooks/images/IMG_2062.jpg"

# %%
from PIL import Image
img = Image.open(IMAGE_PATH)
img.resize((800, 600))
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
alpr(IMAGE_PATH)
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/ALPR/../test_notebooks/images/IMG_2062.jpg: 640x480 378.9ms
# Speed: 4.6ms preprocess, 378.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# '37-TTS-2'
