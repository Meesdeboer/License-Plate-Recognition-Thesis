# %%
import ALPR
from ALPR import alpr
# Out:
# 2024-05-06 19:18:14.261237: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 19:18:14.261306: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 19:18:14.262486: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
IMAGE_PATH = "../test_notebooks/images/seat.webp"

# %%
from PIL import Image
img = Image.open(IMAGE_PATH)
img.resize((600, 600))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
alpr(IMAGE_PATH)
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/ALPR/../test_notebooks/images/seat.webp: 384x640 466.8ms
# Speed: 4.9ms preprocess, 466.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 'S-489-BF'
