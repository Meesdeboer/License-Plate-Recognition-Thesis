# %%
import ALPR
from ALPR import alpr
# Out:
# 2024-05-08 12:10:14.369337: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 12:10:14.369398: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 12:10:14.369426: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
IMAGE_PATH = "../test_notebooks/images/IMG_2078.jpg"

# %%
from PIL import Image
img = Image.open(IMAGE_PATH)
img.resize((600, 600))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
try:
    result = alpr(IMAGE_PATH)
    print(result)
except:
    print("No license plates found in the image.")
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/ALPR/../test_notebooks/images/IMG_2078.jpg: 640x480 (no detections), 496.9ms
# Speed: 4.7ms preprocess, 496.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# No license plates found in the image.
