# %%
from ALPR_for_transfer import alpr_transfer
from ALPR import alpr
from PIL import Image
import os
import numpy as np
# Out:
# 2024-06-08 16:22:26.760505: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 16:22:26.760635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 16:22:26.761812: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
image_path = '../images/1.jpg'

# %%
alpr_transfer(image_path)
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/test_notebooks/test/../images/1.jpg: 640x480 616.9ms
# Speed: 4.2ms preprocess, 616.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
# 'VZF-64-J'

# %%
image_dir = "../../../test_images/platesmania"
image_list = os.listdir(image_dir)
print(len(image_list))
# Out:
# 3245

# %%
for i in range(2631, len(image_list)):
    image_path = os.path.join(image_dir, image_list[i])
    
    try:
        prediction = alpr(image_path)
    except:
        pass

    real_plate = image_list[i].split(".")[0]

    if prediction == real_plate:
        alpr_transfer(image_path)

    print(i)
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/test_notebooks/test/../../../test_images/platesmania/V-845-JV.jpg: 480x640 549.9ms
# Speed: 7.1ms preprocess, 549.9ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
# 2631
#
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/test_notebooks/test/../../../test_images/platesmania/59-GN-HB.jpg: 480x640 447.2ms
# Speed: 3.4ms preprocess, 447.2ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
# 2632
#
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/test_notebooks/test/../../../test_images/platesmania/96-LP-JD.jpg: 480x640 465.3ms
# Speed: 4.1ms preprocess, 465.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/test_notebooks/test/../../../test_images/platesmania/96-LP-JD.jpg: 480x640 475.4ms
# ...

# %%
image_path = '676810.jpg'
alpr_transfer(image_path)
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/test_notebooks/test/676810.jpg: 480x640 939.3ms
# Speed: 23.6ms preprocess, 939.3ms inference, 17.8ms postprocess per image at shape (1, 3, 480, 640)
# 'S-106-XL'

# %%
# resisze image to 640x640 and save
image = Image.open(image_path)
image = image.resize((640, 640))
image.save(image_path)
